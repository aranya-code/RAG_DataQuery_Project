# %% [markdown]
# ### Data Ingestion

# %%
## Document DataStructure

from langchain_core.documents import Document

# %%
## Document DataStructure

from langchain_core.documents import Document

# %%
## Creating a simple text

import os
os.makedirs('../data/text_files', exist_ok=True)

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/text_files/python.txt', encoding = 'utf-8')
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python.txt'}, page_content="Python is a high-level, interpreted programming language known for its readability and simplicity. It was created by Guido van Rossum and first released in 1991. Python emphasizes code readability with its clean, easy-to-understand syntax, making it an ideal choice for both beginners and experienced developers. Its dynamic typing and automatic memory management features contribute to its versatility. Python supports multiple programming paradigms, including object-oriented, imperative, and functional programming. With a vast collection of libraries and frameworks, Python is widely used in fields such as web development, data analysis, machine learning, automation, and scientific computing. Python's cross-platform compatibility and extensive community support make it a popular choice for developers around the world.\n")]

# %%
### Directory Text Loader

from langchain_community.document_loaders import DirectoryLoader, TextLoader

dir_loader=DirectoryLoader(
    '../data/text_files',
    glob='**/*.txt',
    loader_cls = TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress = True
)

documents = dir_loader.load()
documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 999.00it/s]
# [Document(metadata={'source': '..\\data\\text_files\\python.txt'}, page_content="Python is a high-level, interpreted programming language known for its readability and simplicity. It was created by Guido van Rossum and first released in 1991. Python emphasizes code readability with its clean, easy-to-understand syntax, making it an ideal choice for both beginners and experienced developers. Its dynamic typing and automatic memory management features contribute to its versatility. Python supports multiple programming paradigms, including object-oriented, imperative, and functional programming. With a vast collection of libraries and frameworks, Python is widely used in fields such as web development, data analysis, machine learning, automation, and scientific computing. Python's cross-platform compatibility and extensive community support make it a popular choice for developers around the world.\n"),
#  Document(metadata={'source': '..\\data\\text_files\\RAG.txt'}, page_content='RAG (Retrieve and Generate) is a framework that combines information retrieval with text generation to enhance the accuracy and relevance of responses. It typically consists of two main components: the retrieval model and the generation model.\n\n1. **Retrieve**: The first step involves retrieving relevant documents, snippets, or data from a large corpus using a retrieval model, often based on similarity search techniques such as TF-IDF or dense embeddings (e.g., using models like BERT or FAISS).\n\n2. **Generate**: After relevant information is retrieved, a generative model, such as GPT, is used to generate a response by combining the retrieved information with language generation capabilities.\n\nRAG is useful for tasks like question answering and summarization, where the generative model can leverage external knowledge to produce more accurate, contextually relevant answers. It allows for handling situations where the generative model alone might not have sufficient information, making it a powerful tool for combining retrieval-based approaches with the flexibility of language generation.\n')]

# %%
### Directory PDF Loader

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader=DirectoryLoader(
    '../data/pdf_files',
    glob='**/*.pdf',
    loader_cls = PyMuPDFLoader,
    show_progress = True
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 71.75it/s]
# [Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-001.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-001.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-001\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-002.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-002.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-002\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-003.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-003.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-003\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-004.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-004.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-004\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-005.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-005.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-005\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-006.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-006.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-006\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-007.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-007.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-007\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-008.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-008.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-008\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-009.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-009.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-009\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-010.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-010.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-010\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-011.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-011.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-011\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-012.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-012.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-012\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-013.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-013.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-013\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-014.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-014.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-014\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-015.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-015.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-015\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-016.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-016.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-016\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-017.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-017.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-017\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-018.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-018.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-018\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-019.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-019.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-019\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20251105025513', 'source': '..\\data\\pdf_files\\invoice_INV-20251105-020.pdf', 'file_path': '..\\data\\pdf_files\\invoice_INV-20251105-020.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251105025513', 'page': 0}, page_content='Invoice\nInvoice Number: INV-20251105-020\nDate: 2025-11-05\nYour Company Name\n1234 Business St.\nCity, State, ZIP\nPhone: (123) 456-7890\nEmail: contact@yourcompany.com\nBill To:\nCustomer Name\n5678 Client Ave.\nCity, State, ZIP\nDescription\nQty\nUnit Price\nTotal\nProduct A\n2\n$10.00\n$20.00\nProduct B\n1\n$15.50\n$15.50\nService C\n3\n$7.25\n$21.75\nTotal Amount:\n$57.25\nPayment Terms: Due within 30 days. Late payments will incur a 5% late fee per month.')]
